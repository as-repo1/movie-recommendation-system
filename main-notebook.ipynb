# %%
#imprt libraries
import numpy as np
import pandas as pd
import ast

# %%
movies_raw = pd.read_csv('tmdb_5000_movies.csv')
credits_raw = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies_raw.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies_raw.shape
# Out:
# (4803, 20)

# %%
credits_raw.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
credits_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
movies = movies_raw.merge(credits_raw,on='title')

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                                                 cast  \
# ...

# %%
# convert the string to list
def convert(text):
    l=[]
    for i in ast.literal_eval(text):
        l.append(i['name'])
    return l

# %%
# drop duplicates
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 16, "name": "Animation"}, {"id": 35, "name": "Comedy"}, {"id": 80, "name": "Crime"}, {"id": 99, "name": "Documentary"}, {"id": 18, "name": "Drama"}, {"id": 10751, "name": "Family"}, {"id": 14, "name": "Fantasy"}, {"id": 36, "name": "History"}, {"id": 27, "name": "Horror"}, {"id": 10402, "name": "Music"}, {"id": 9648, "name": "Mystery"}, {"id": 10749, "name": "Romance"}, {"id": 878, "name": "Science Fiction"}, {"id": 10770, "name": "TV Movie"}, {"id": 53, "name": "Thriller"}, {"id": 10752, "name": "War"}, {"id": 37, "name": "Western"}]')


ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    l =[]
    counter=0
    for i in ast.literal_eval(text):
        if counter < 3:
            l.append(i['name'])
            counter+=1
    return l

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
#
#                                                 cast  \
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(10)
# Out:
#       movie_id                                title  \
# 4639    300327                          Death Calls
# 860      42297                            Burlesque
# 3742     10331             Night of the Living Dead
# 1029       593                              Solaris
# 2024       688        The Bridges of Madison County
# 2107     76203                     12 Years a Slave
# 2143     10139                                 Milk
# 3686    300706               Let's Kill Ward's Wife
# 22       57158  The Hobbit: The Desolation of Smaug
# 11       10764                    Quantum of Solace
#
#                                                overview  \
# 4639  An action-packed love story on the Mexican bor...
# 860   The Burlesque Lounge has its best days behind ...
# 3742  A group of people try to survive an attack of ...
# 1029  Ground control has been receiving strange tran...
# 2024  Photographer Robert Kincaid wanders into the l...
# ...

# %%
def collapse(L):
    L1=[]
    for i in L:
        L1.append(i.replace(' ',''))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
# movies['production_companies'] = movies['production_companies'].apply(collapse)
# movies['production_countries'] = movies['production_countries'].apply(collapse)
# movies['spoken_languages'] = movies['spoken_languages'].apply(collapse)

# %%
movies.sample(3)
# Out:
#       movie_id                  title  \
# 1526      5494  George and the Dragon
# 3249     10885                Shutter
# 2143     10139                   Milk
#
#                                                overview  \
# 1526  A knight returning from the Crusades takes on ...
# 3249  A newly married couple discovers disturbing, g...
# 2143  The story of California's first openly gay ele...
#
#                            genres  \
# 1526                  [Adventure]
# 3249  [Horror, Mystery, Thriller]
# 2143             [History, Drama]
#
#                                                keywords  \
# 1526                   [swordplay, hero, sword, dragon]
# 3249  [japan, suicide, photographer, honeymoon, nigh...
# 2143  [gay, sanfrancisco, homophobia, mayor, biograp...
#
#                                              cast              crew
# 1526   [JamesPurefoy, PiperPerabo, PatrickSwayze]        [TomReeve]
# 3249  [JoshuaJackson, RachaelTaylor, MegumiOkina]  [MasayukiOchiai]
# ...

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
new.sample(5)
# new.head()
# Out:
#       movie_id                    title  \
# 590       9882                The Siege
# 3231    185008  Yeh Jawaani Hai Deewani
# 1098      2185              Big Trouble
# 3253     11971   Much Ado About Nothing
# 296       9946              End of Days
#
#                                                    tags
# 590   [The, secret, US, abduction, of, a, suspected,...
# 3231  [Yeh, Jawaani, Hai, Deewani, features, two, po...
# 1098  [The, story, of, how, a, mysterious, suitcase,...
# 3253  [In, this, Shakespearean, farce,, Hero, and, h...
# 296   [On, December, 28th,, 1999,, the, citizens, of...

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new.shape
# Out:
# (4806, 3)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vector)
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]])

# %%
# to retrieve the index of a specific movie in the DataFrame new. It's finding the index corresponding to the movie with the title 'The Dark Knight Rises'. 
new[new['title'] == 'The Dark Knight Rises'].index[0] # 3
# Out:
# 3

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend("Titanic")
# Out:
# Captain Phillips
# The Notebook
# In the Heart of the Sea
# Ghost Ship
# Poseidon

# %%
# import gradio as gr

# def recommend_movies(movie_title, num_recommendations=5):
#     index = new[new['title'] == movie_title].index[0]
#     distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    
#     # Limit the number of recommendations based on the slider value
#     recommended_movies = [new.iloc[i[0]].title for i in distances[1:num_recommendations+1]]
#     return "\n".join(recommended_movies)

# demo = gr.Interface(
#     fn=recommend_movies, 
#     inputs=["text", gr.inputs.Slider(1, 13, step=1)],  # step=1 to allow only integer values
#     outputs="text",  # Use "text" type for displaying recommendations
#     live=True
# )
# demo.launch()
# # demo.launch(share=True) #for sharing the link for public

# %% [markdown]
# ## using pickle

# %%
import pickle

pickle.dump(new, open('movies.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))
